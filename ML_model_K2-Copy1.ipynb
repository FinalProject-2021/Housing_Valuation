# %%
# Required Modules
import pandas as pd
import numpy as np

# %%
import warnings
warnings.filterwarnings("ignore")

from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
# Read in CSV data
data = pd.read_csv('Resources/Final_Data.csv')

data.head()
# Out:
#    Zip_Code        Date  Date_Code  Year  Month  Sale_Price  Interest_Rate  \
# 0     32003  2019-01-01     201901  2019      1    244950.0         4.4640
# 1     32003  2019-02-01     201902  2019      2    270000.0         4.3700
# 2     32003  2019-03-01     201903  2019      3    275000.0         4.2650
# 3     32003  2019-04-01     201904  2019      4    264500.0         4.1425
# 4     32003  2019-05-01     201905  2019      5    281000.0         4.0720
#
#    Property_Tax  Rent_Price  Household_Income  ...  FTE_Employed  Unemployed  \
# 0          3778        1113           94154.0  ...         10671        1069
# 1          3778        1113           94154.0  ...         10671        1069
# 2          3778        1113           94154.0  ...         10671        1069
# 3          3778        1113           94154.0  ...         10671        1069
# 4          3778        1113           94154.0  ...         10671        1069
#
#    Expense_Index  Average_Commute  Crime_Index Loan_Amount  Loan_Term  \
# 0            104               35           28    195960.0      360.0
# 1            104               35           28    216000.0      360.0
# 2            104               35           28    220000.0      360.0
# 3            104               35           28    211600.0      360.0
# 4            104               35           28    224800.0      360.0
#
#      Loan_R  Loan_Payment  Home_Affordability
# 0  1.003720    988.713278            0.126012
# 1  1.003642   1077.819242            0.137369
# 2  1.003554   1084.200547            0.138182
# 3  1.003452   1027.671397            0.130978
# 4  1.003393   1082.581718            0.137976
#
# [5 rows x 30 columns]

# %%
data.shape
# Out:
# (24382, 30)

# %% [markdown]
# ## Set aside 2021 data

# %%
ml_data_21 = data.loc[data.Year == 2021]
ml_data_21 = ml_data_21[['Zip_Code', 'Year', 'Month', 'Mobility_Rate', 'Expense_Index', 'Crime_Index' , 'Total_Vacant', 'Total_Dwellings', 'Total_Sales', 'FHA_Count', 'Home_Affordability', 'Rent_Affordability', 'Sale_Price' ]]
ml_data_21 = ml_data_21.sort_values(by = ['Zip_Code', 'Year', 'Month'], ascending = [True, True, True])

# %%
# Add columns for future months sales prices
ml_data_21['Last_Month_Price'] = ml_data_21.groupby(['Zip_Code'])['Sale_Price'].shift()
ml_data_21['Last_Month_Diff'] = ml_data_21.groupby(['Zip_Code'])['Last_Month_Price'].diff()
ml_data_21['Last_2Month_Price'] = ml_data_21.groupby(['Zip_Code'])['Sale_Price'].shift(2)
ml_data_21['Last_2Month_Diff'] = ml_data_21.groupby(['Zip_Code'])['Last_2Month_Price'].diff()
ml_data_21['Last_3Month_Price'] = ml_data_21.groupby(['Zip_Code'])['Sale_Price'].shift(3)
ml_data_21['Last_3Month_Diff'] = ml_data_21.groupby(['Zip_Code'])['Last_3Month_Price'].diff()
# Drop columns not needed for X values
ml_data_21 = ml_data_21.drop(columns=['Year', 'Month'])
ml_data_21.replace([np.inf, -np.inf], np.nan, inplace=True)
ml_data_21.dropna(inplace=True)
ml_data_21.head()
# Out:
#        Zip_Code  Mobility_Rate  Expense_Index  Crime_Index  Total_Vacant  \
# 22615     34756       0.063615             99          106           180
# 22616     34756       0.063615             99          106           180
# 22669     34758       0.130450            118          387          2886
# 22670     34758       0.130450            118          387          2886
# 22723     34759       0.133040            103          203          3780
#
#        Total_Dwellings  Total_Sales  FHA_Count  Home_Affordability  \
# 22615             1519            7          1            0.245128
# 22616             1519            7          1            0.245128
# 22669            15628           30         32            0.191097
# 22670            15628           30         32            0.191097
# 22723            17943           67         67            0.177318
#
#        Rent_Affordability  Sale_Price  Last_Month_Price  Last_Month_Diff  \
# 22615            0.211160    449900.0          362250.0              0.0
# 22616            0.211160    449900.0          449900.0          87650.0
# 22669            0.296244    250000.0          227100.0              0.0
# 22670            0.296244    250000.0          250000.0          22900.0
# 22723            0.241901    220000.0          215000.0              0.0
#
#        Last_2Month_Price  Last_2Month_Diff  Last_3Month_Price  \
# 22615           362250.0           34750.0           327500.0
# 22616           362250.0               0.0           362250.0
# 22669           227100.0            7200.0           219900.0
# 22670           227100.0               0.0           227100.0
# 22723           215000.0           13800.0           201200.0
#
#        Last_3Month_Diff
# 22615               0.0
# 22616           34750.0
# 22669               0.0
# 22670            7200.0
# 22723               0.0

# %% [markdown]
# ##

# %%
# Select features for X
ml_data = data[['Zip_Code', 'Year', 'Month', 'Mobility_Rate', 'Expense_Index', 'Crime_Index' , 'Total_Vacant', 'Total_Dwellings', 'Total_Sales', 'FHA_Count', 'Home_Affordability', 'Rent_Affordability', 'Sale_Price' ]]

ml_data.shape
# Out:
# (24382, 13)

# %%
# Drop 2021 data
index_names = ml_data[ml_data['Year'] == 2021 ].index
ml_data.drop(index_names, inplace = True)

ml_data.shape
# Out:
# (21764, 13)

# %%
# Create copy to try three-month training data
ml_data_3mo = ml_data.sort_values(by = ['Zip_Code', 'Year', 'Month'], ascending = [True, True, True])
ml_data_3mo.loc[ml_data_3mo.Year == 2020, "Month"] += 12

ml_data_3mo.head(21764)
# Out:
#        Zip_Code  Year  Month  Mobility_Rate  Expense_Index  Crime_Index  \
# 0         32003  2019      1       0.182327            104           28
# 1         32003  2019      2       0.182327            104           28
# 2         32003  2019      3       0.182327            104           28
# 3         32003  2019      4       0.182327            104           28
# 4         32003  2019      5       0.182327            104           28
# ...         ...   ...    ...            ...            ...          ...
# 24371     34997  2020     22       0.143471             91          113
# 24372     34997  2020     23       0.143471             91          113
# 24373     34997  2020     23       0.143471             91          113
# 24374     34997  2020     24       0.143471             91          113
# 24375     34997  2020     24       0.143471             91          113
#
#        Total_Vacant  Total_Dwellings  Total_Sales  FHA_Count  \
# 0               704            11724           32          7
# 1               704            11724           41          2
# 2               704            11724           21          7
# 3               704            11724           42          3
# 4               704            11724           66          8
# ...             ...              ...          ...        ...
# 24371          2976            21551          139         17
# 24372          2976            21551          132         11
# 24373          2976            21551          132         11
# 24374          2976            21551          142         16
# 24375          2976            21551          142         16
#
#        Home_Affordability  Rent_Affordability  Sale_Price
# 0                0.126012            0.141853    244950.0
# 1                0.137369            0.141853    270000.0
# 2                0.138182            0.141853    275000.0
# 3                0.130978            0.141853    264500.0
# 4                0.137976            0.141853    281000.0
# ...                   ...                 ...         ...
# 24371            0.192070            0.247189    285000.0
# 24372            0.173497            0.247189    259750.0
# 24373            0.173497            0.247189    259750.0
# 24374            0.196301            0.247189    297000.0
# 24375            0.196301            0.247189    297000.0
#
# [21764 rows x 13 columns]

# %%
# Add columns for future months' sales prices
ml_data_3mo['Last_Month_Price'] = ml_data_3mo.groupby(['Zip_Code'])['Sale_Price'].shift()
ml_data_3mo['Last_Month_Diff'] = ml_data_3mo.groupby(['Zip_Code'])['Last_Month_Price'].diff()

ml_data_3mo['Future_Month_Price'] = ml_data_3mo.groupby(['Zip_Code'])['Sale_Price'].shift(-1)
ml_data_3mo['Future_Month_Diff'] = ml_data_3mo.groupby(['Zip_Code'])['Future_Month_Price'].diff()

ml_data_3mo['Future_2Month_Price'] = ml_data_3mo.groupby(['Zip_Code'])['Sale_Price'].shift(-2)
ml_data_3mo['Future_2Month_Diff'] = ml_data_3mo.groupby(['Zip_Code'])['Future_2Month_Price'].diff()

ml_data_3mo['Future_3Month_Price'] = ml_data_3mo.groupby(['Zip_Code'])['Sale_Price'].shift(-3)
ml_data_3mo['Future_3Month_Diff'] = ml_data_3mo.groupby(['Zip_Code'])['Future_3Month_Price'].diff()

ml_data_3mo.head()
# Out:
#    Zip_Code  Year  Month  Mobility_Rate  Expense_Index  Crime_Index  \
# 0     32003  2019      1       0.182327            104           28
# 1     32003  2019      2       0.182327            104           28
# 2     32003  2019      3       0.182327            104           28
# 3     32003  2019      4       0.182327            104           28
# 4     32003  2019      5       0.182327            104           28
#
#    Total_Vacant  Total_Dwellings  Total_Sales  FHA_Count  ...  \
# 0           704            11724           32          7  ...
# 1           704            11724           41          2  ...
# 2           704            11724           21          7  ...
# 3           704            11724           42          3  ...
# 4           704            11724           66          8  ...
#
#    Rent_Affordability  Sale_Price  Last_Month_Price  Last_Month_Diff  \
# 0            0.141853    244950.0               NaN              NaN
# 1            0.141853    270000.0          244950.0              NaN
# 2            0.141853    275000.0          270000.0          25050.0
# 3            0.141853    264500.0          275000.0           5000.0
# 4            0.141853    281000.0          264500.0         -10500.0
#
#    Future_Month_Price  Future_Month_Diff  Future_2Month_Price  \
# 0            270000.0                NaN             275000.0
# 1            275000.0             5000.0             264500.0
# 2            264500.0           -10500.0             281000.0
# 3            281000.0            16500.0             275000.0
# 4            275000.0            -6000.0             282500.0
#
#    Future_2Month_Diff  Future_3Month_Price  Future_3Month_Diff
# 0                 NaN             264500.0                 NaN
# 1            -10500.0             281000.0             16500.0
# 2             16500.0             275000.0             -6000.0
# 3             -6000.0             282500.0              7500.0
# 4              7500.0             269577.0            -12923.0
#
# [5 rows x 21 columns]

# %%
# Drop columns not needed for X values
# Keeping Month this time
ml_data_3mo = ml_data_3mo.drop(columns=['Year', 'Month'])

ml_data_3mo.shape
# Out:
# (21764, 19)

# %%
ml_data_3mo.replace([np.inf, -np.inf], np.nan, inplace=True)
ml_data_3mo.dropna(inplace=True)

ml_data_3mo.shape
# Out:
# (17256, 19)

# %%
ml_data_3mo.head()
# Out:
#    Zip_Code  Mobility_Rate  Expense_Index  Crime_Index  Total_Vacant  \
# 2     32003       0.182327            104           28           704
# 3     32003       0.182327            104           28           704
# 4     32003       0.182327            104           28           704
# 5     32003       0.182327            104           28           704
# 6     32003       0.182327            104           28           704
#
#    Total_Dwellings  Total_Sales  FHA_Count  Home_Affordability  \
# 2            11724           21          7            0.138182
# 3            11724           42          3            0.130978
# 4            11724           66          8            0.137976
# 5            11724           43          3            0.130690
# 6            11724           90          7            0.133641
#
#    Rent_Affordability  Sale_Price  Last_Month_Price  Last_Month_Diff  \
# 2            0.141853    275000.0          270000.0          25050.0
# 3            0.141853    264500.0          275000.0           5000.0
# 4            0.141853    281000.0          264500.0         -10500.0
# 5            0.141853    275000.0          281000.0          16500.0
# 6            0.141853    282500.0          275000.0          -6000.0
#
#    Future_Month_Price  Future_Month_Diff  Future_2Month_Price  \
# 2            264500.0           -10500.0             281000.0
# 3            281000.0            16500.0             275000.0
# 4            275000.0            -6000.0             282500.0
# 5            282500.0             7500.0             269577.0
# 6            269577.0           -12923.0             286000.0
#
#    Future_2Month_Diff  Future_3Month_Price  Future_3Month_Diff
# 2             16500.0             275000.0             -6000.0
# 3             -6000.0             282500.0              7500.0
# 4              7500.0             269577.0            -12923.0
# 5            -12923.0             286000.0             16423.0
# 6             16423.0             258000.0            -28000.0

# %% [markdown]
# ## Do train/test

# %%
# Set X and y values
y = ml_data_3mo['Future_3Month_Price'].values

X = ml_data_3mo.drop(columns='Future_3Month_Price')

feature_names = X.columns

X
# Out:
#        Zip_Code  Mobility_Rate  Expense_Index  Crime_Index  Total_Vacant  \
# 2         32003       0.182327            104           28           704
# 3         32003       0.182327            104           28           704
# 4         32003       0.182327            104           28           704
# 5         32003       0.182327            104           28           704
# 6         32003       0.182327            104           28           704
# ...         ...            ...            ...          ...           ...
# 24368     34997       0.143471             91          113          2976
# 24369     34997       0.143471             91          113          2976
# 24370     34997       0.143471             91          113          2976
# 24371     34997       0.143471             91          113          2976
# 24372     34997       0.143471             91          113          2976
#
#        Total_Dwellings  Total_Sales  FHA_Count  Home_Affordability  \
# 2                11724           21          7            0.138182
# 3                11724           42          3            0.130978
# 4                11724           66          8            0.137976
# 5                11724           43          3            0.130690
# 6                11724           90          7            0.133641
# ...                ...          ...        ...                 ...
# 24368            21551          115         18            0.173776
# 24369            21551          115         18            0.173776
# 24370            21551          139         17            0.192070
# 24371            21551          139         17            0.192070
# 24372            21551          132         11            0.173497
#
#        Rent_Affordability  Sale_Price  Last_Month_Price  Last_Month_Diff  \
# 2                0.141853    275000.0          270000.0          25050.0
# 3                0.141853    264500.0          275000.0           5000.0
# 4                0.141853    281000.0          264500.0         -10500.0
# 5                0.141853    275000.0          281000.0          16500.0
# 6                0.141853    282500.0          275000.0          -6000.0
# ...                   ...         ...               ...              ...
# 24368            0.247189    256000.0          251000.0              0.0
# 24369            0.247189    256000.0          256000.0           5000.0
# 24370            0.247189    285000.0          256000.0              0.0
# 24371            0.247189    285000.0          285000.0          29000.0
# 24372            0.247189    259750.0          285000.0              0.0
#
#        Future_Month_Price  Future_Month_Diff  Future_2Month_Price  \
# 2                264500.0           -10500.0             281000.0
# 3                281000.0            16500.0             275000.0
# 4                275000.0            -6000.0             282500.0
# 5                282500.0             7500.0             269577.0
# 6                269577.0           -12923.0             286000.0
# ...                   ...                ...                  ...
# 24368            256000.0                0.0             285000.0
# 24369            285000.0            29000.0             285000.0
# 24370            285000.0                0.0             259750.0
# 24371            259750.0           -25250.0             259750.0
# 24372            259750.0                0.0             297000.0
#
#        Future_2Month_Diff  Future_3Month_Diff
# 2                 16500.0             -6000.0
# 3                 -6000.0              7500.0
# 4                  7500.0            -12923.0
# 5                -12923.0             16423.0
# 6                 16423.0            -28000.0
# ...                   ...                 ...
# 24368             29000.0                 0.0
# 24369                 0.0            -25250.0
# 24370            -25250.0                 0.0
# 24371                 0.0             37250.0
# 24372             37250.0                 0.0
#
# [17256 rows x 18 columns]

# %%
# Do test-train-split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
print(len(X_test))
print(len(y_test))
# Out:
# 4314
# 4314

# %%
# Fit Random Forest Regressor model
rfr_model = RandomForestRegressor(n_estimators=1000, n_jobs=-1, random_state=42)
rfr_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=1000, n_jobs=-1, random_state=42)

# %%
# Get R2 score
print(f"Training Data Score: {rfr_model.score(X_train, y_train)}")
print(f"Testing Data Score: {rfr_model.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.9960245761482237
# Testing Data Score: 0.9906535567093204

# %% [markdown]
# ## Predict

# %%
# Use predict on 2021 data
y_21 = ml_data_21['Future_3Month_Price'].values
X_21 = ml_data_21.drop(columns='Future_3Month_Price')

y_pred = rfr_model.predict(X_21)
y_pred

# %%
# Predict 2021 data on specific zip code
zip_data = ml_data_21.loc[ml_data_21.Zip_Code == 34756]
y_zip = zip_data['Last_3Month_Price'].values
x_zip = zip_data.drop(columns='Last_3Month_Price')
# y_zip_pred = rfr_model.predict(x_zip)
# y_zip_pred
zip_data
# y_zip
# x_zip
# Out:
#        Zip_Code  Mobility_Rate  Expense_Index  Crime_Index  Total_Vacant  \
# 22615     34756       0.063615             99          106           180
# 22616     34756       0.063615             99          106           180
#
#        Total_Dwellings  Total_Sales  FHA_Count  Home_Affordability  \
# 22615             1519            7          1            0.245128
# 22616             1519            7          1            0.245128
#
#        Rent_Affordability  Sale_Price  Last_Month_Price  Last_Month_Diff  \
# 22615             0.21116    449900.0          362250.0              0.0
# 22616             0.21116    449900.0          449900.0          87650.0
#
#        Last_2Month_Price  Last_2Month_Diff  Last_3Month_Price  \
# 22615           362250.0           34750.0           327500.0
# 22616           362250.0               0.0           362250.0
#
#        Last_3Month_Diff
# 22615               0.0
# 22616           34750.0
