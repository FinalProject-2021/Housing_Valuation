# %%
import pandas as pd
import os

# %%
file = os.path.join('FHA_loans', 'FHA_Jan2019.xlsx')

# %%
jan_2019 = pd.read_excel(file)
jan_2019.head()
# Out:
#   Property State Property City Property County  Property Zip  \
# 0             AK     ANCHORAGE       ANCHORAGE         99501
# 1             AK     ANCHORAGE       ANCHORAGE         99502
# 2             AK     ANCHORAGE       ANCHORAGE         99502
# 3             AK     ANCHORAGE       ANCHORAGE         99502
# 4             AK     ANCHORAGE       ANCHORAGE         99502
#
#   Origination Mortgagee/Sponsor Originator  Originating Mortgagee Number  \
# 0                  RESIDENTIAL MORTGAGE LLC                        12511
# 1                      FIRST RATE FINANCIAL                Not Available
# 2                      FIRST RATE FINANCIAL                Not Available
# 3                      FIRST RATE FINANCIAL                Not Available
# 4                       GUARANTEED RATE INC                        19895
#
#                            Sponsor Name Sponsor Number Down Payment Source  \
# 0                         Not Available  Not Available            Borrower
# 1                CALIBER HOME LOANS INC          30992            Relative
# 2                CALIBER HOME LOANS INC          30992            Borrower
# 3  UNITED SHORE FINANCIAL SERVICES, LLC          71845            Borrower
# 4                         Not Available  Not Available            Borrower
#
#   Non Profit Number Product Type Loan Purpose  Property Type  Interest Rate  \
# 0         Not Avail   Fixed Rate     Purchase  Single Family          4.625
# 1         Not Avail   Fixed Rate     Purchase  Single Family          4.990
# 2         Not Avail   Fixed Rate     Purchase  Single Family          4.250
# 3         Not Avail   Fixed Rate     Purchase  Single Family          4.750
# 4         Not Avail   Fixed Rate     Purchase  Single Family          4.625
#
#    Original Mortgage Amount  Endorsement  Year  Endorsement Month
# 0                    176739               2019                   1
# 1                    265109               2019                   1
# 2                    417302               2019                   1
# 3                    288085               2019                   1
# 4                    358388               2019                   1

# %%
# os.chdir('FHA_loans')
path = os.getcwd()
files = os.listdir(path)
files
# Out:
# ['FHA_Apr2019.xlsx',
#  'FHA_Apr2020.xlsx',
#  'FHA_Aug2019.xlsx',
#  'FHA_Aug2020.xlsx',
#  'FHA_Dec2019.xlsx',
#  'FHA_Dec2020.xlsx',
#  'FHA_Feb2019.xlsx',
#  'FHA_Feb2020.xlsx',
#  'FHA_Jan2019.xlsx',
#  'FHA_Jan2020.xlsx',
#  'FHA_Jul2019.xlsx',
#  'FHA_Jul2020.xlsx',
#  'FHA_Jun2019.xlsx',
#  'FHA_Jun2020.xlsx',
#  'FHA_Mar2019.xlsx',
#  'FHA_Mar2020.xlsx',
#  'FHA_May2019.xlsx',
#  'FHA_May2020.xlsx',
#  'FHA_Nov2019.xlsx',
#  'FHA_Nov2020.xlsx',
#  'FHA_Oct2019.xlsx',
#  'FHA_Oct2020.xlsx',
#  'FHA_Sep2019.xlsx',
#  'FHA_Sep2020.xlsx']

# %%
excel_files = [f for f in files if f[-4:] == 'xlsx']
excel_files
# Out:
# ['FHA_Apr2019.xlsx',
#  'FHA_Apr2020.xlsx',
#  'FHA_Aug2019.xlsx',
#  'FHA_Aug2020.xlsx',
#  'FHA_Dec2019.xlsx',
#  'FHA_Dec2020.xlsx',
#  'FHA_Feb2019.xlsx',
#  'FHA_Feb2020.xlsx',
#  'FHA_Jan2019.xlsx',
#  'FHA_Jan2020.xlsx',
#  'FHA_Jul2019.xlsx',
#  'FHA_Jul2020.xlsx',
#  'FHA_Jun2019.xlsx',
#  'FHA_Jun2020.xlsx',
#  'FHA_Mar2019.xlsx',
#  'FHA_Mar2020.xlsx',
#  'FHA_May2019.xlsx',
#  'FHA_May2020.xlsx',
#  'FHA_Nov2019.xlsx',
#  'FHA_Nov2020.xlsx',
#  'FHA_Oct2019.xlsx',
#  'FHA_Oct2020.xlsx',
#  'FHA_Sep2019.xlsx',
#  'FHA_Sep2020.xlsx']

# %%
df = pd.DataFrame()

# %%
for e in excel_files:
    data = pd.read_excel(e)
    df = df.append(data)

# %%
df
# Out:
#       Property State Property City Property County Property Zip  \
# 0                 AK     ANCHORAGE       ANCHORAGE        99501
# 1                 AK     ANCHORAGE       ANCHORAGE        99501
# 2                 AK     ANCHORAGE       ANCHORAGE        99502
# 3                 AK     ANCHORAGE       ANCHORAGE        99502
# 4                 AK     ANCHORAGE       ANCHORAGE        99502
# ...              ...           ...             ...          ...
# 81252             WY       WORLAND        WASHAKIE        82401
# 81253             WY       WORLAND        WASHAKIE        82401
# 81254             WY       WORLAND        WASHAKIE        82401
# 81255             WY       WORLAND        WASHAKIE        82401
# 81256             WY     NEWCASTLE          WESTON        82701
#
#       Origination Mortgagee/Sponsor Originator  Originating Mortgagee Number  \
# 0                          FIRST RATE FINANCIAL                Not Available
# 1                      RESIDENTIAL MORTGAGE LLC                        12511
# 2                ALASKAUSA MORTGAGE COMPANY LLC                        75641
# 3                         MOVEMENT MORTGAGE LLC                        26264
# 4                      RESIDENTIAL MORTGAGE LLC                        12511
# ...                                         ...                          ...
# 81252                       SECURITY STATE BANK                Not Available
# 81253                          CMG MORTGAGE INC                        78442
# 81254                     PINNACLE BANK WYOMING                        58043
# 81255                     PINNACLE BANK WYOMING                        58043
# 81256                  STILLWATER MORTGAGE, INC                Not Available
#
#                           Sponsor Name Sponsor Number Down Payment Source  \
# 0               CALIBER HOME LOANS INC          30992            Borrower
# 1                        Not Available  Not Available            Borrower
# 2      ALASKA USA FEDERAL CREDIT UNION          59034            Borrower
# 3                        Not Available  Not Available            Borrower
# 4                        Not Available  Not Available            Borrower
# ...                                ...            ...                 ...
# 81252                OPEN MORTGAGE LLC          21548            Relative
# 81253                    Not Available  Not Available            Borrower
# 81254                    Not Available  Not Available            Borrower
# 81255                    Not Available  Not Available            Borrower
# 81256        EQUITY PRIME MORTGAGE LLC          27909            Borrower
#
#       Non Profit Number Product Type Loan Purpose  Property Type  \
# 0             Not Avail   Fixed Rate     Purchase  Single Family
# 1             Not Avail   Fixed Rate     Purchase          Condo
# 2             Not Avail   Fixed Rate     Purchase          Condo
# 3             Not Avail   Fixed Rate     Purchase  Single Family
# 4             Not Avail   Fixed Rate     Purchase          Condo
# ...                 ...          ...          ...            ...
# 81252         Not Avail   Fixed Rate     Purchase  Single Family
# 81253         Not Avail   Fixed Rate     Purchase  Single Family
# 81254         Not Avail   Fixed Rate     Purchase  Single Family
# 81255         Not Avail   Fixed Rate     Purchase  Single Family
# 81256         Not Avail   Fixed Rate     Purchase  Single Family
#
#       Interest Rate Original Mortgage Amount Endorsement  Year  \
# 0             3.875                   343660              2019
# 1             4.375                   245471              2019
# 2             4.875                   157102              2019
# 3             4.375                   140409              2019
# 4               4.5                   191468              2019
# ...             ...                      ...               ...
# 81252          3.25                   157102              2020
# 81253          3.25                   110975              2020
# 81254         2.875                   157102              2020
# 81255         3.125                   152093              2020
# 81256         4.625                   196886              2020
#
#       Endorsement Month
# 0                      4
# 1                      4
# 2                      4
# 3                      4
# 4                      4
# ...                  ...
# 81252                  9
# 81253                  9
# 81254                  9
# 81255                  9
# 81256                  9
#
# [1609664 rows x 17 columns]
