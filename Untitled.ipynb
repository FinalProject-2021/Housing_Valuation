# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./Resources/Final_Data.csv')
df
# Out:
#        Zip_Code        Date  Year  Month  Sale_Price  Interest_Rate  \
# 0         32003  2019-01-01  2019      1    244950.0         4.4640
# 1         32003  2019-02-01  2019      2    270000.0         4.3700
# 2         32003  2019-03-01  2019      3    275000.0         4.2650
# 3         32003  2019-04-01  2019      4    264500.0         4.1425
# 4         32003  2019-05-01  2019      5    281000.0         4.0720
# ...         ...         ...   ...    ...         ...            ...
# 21759     34997  2020-10-01  2020     10    285000.0         2.8340
# 21760     34997  2020-11-01  2020     11    259750.0         2.7650
# 21761     34997  2020-11-01  2020     11    259750.0         2.7650
# 21762     34997  2020-12-01  2020     12    297000.0         2.6840
# 21763     34997  2020-12-01  2020     12    297000.0         2.6840
#
#        Property_Tax  Rent_Price  Household_Income  Rent_Affordability  ...  \
# ...

# %%
df = df.drop_duplicates()

# %%
df1 = df.assign(delta_A=df.Sale_Price.diff().fillna(0).astype(int))
df1
# Out:
#        Zip_Code        Date  Year  Month  Sale_Price  Interest_Rate  \
# 0         32003  2019-01-01  2019      1    244950.0         4.4640
# 1         32003  2019-02-01  2019      2    270000.0         4.3700
# 2         32003  2019-03-01  2019      3    275000.0         4.2650
# 3         32003  2019-04-01  2019      4    264500.0         4.1425
# 4         32003  2019-05-01  2019      5    281000.0         4.0720
# ...         ...         ...   ...    ...         ...            ...
# 21754     34997  2020-08-01  2020      8    251000.0         2.9350
# 21756     34997  2020-09-01  2020      9    256000.0         2.8900
# 21758     34997  2020-10-01  2020     10    285000.0         2.8340
# 21760     34997  2020-11-01  2020     11    259750.0         2.7650
# 21762     34997  2020-12-01  2020     12    297000.0         2.6840
#
#        Property_Tax  Rent_Price  Household_Income  Rent_Affordability  ...  \
# ...

# %%
delta = pd.Series(index=['delta'])
for index, row in data.iterrows():
#     print(index)
#     print(row['Zip_Code'])
    row2 = row + 1
    if (row["Zip_Code"] == [row+1]["Zip_Code"]):
        print(row['Zip_Code'])
#         delta[index] = data[index+1]["Sales_Price"]-data[index]["Sale_Price"]
# data["delta"] = delta
# Out:
# <ipython-input-5-32a0dacc187f>:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   delta = pd.Series(index=['delta'])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     142     try:
# --> 143         result = expressions.evaluate(op, left, right)
#     144     except TypeError:
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     232         if use_numexpr:
# --> 233             return _evaluate(op, op_str, a, b)  # type: ignore
#     234     return _evaluate_standard(op, op_str, a, b)
#
# ...
