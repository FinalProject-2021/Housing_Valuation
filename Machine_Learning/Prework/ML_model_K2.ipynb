# %%
# Required Modules
import pandas as pd
import numpy as np

# %%
import warnings
warnings.filterwarnings("ignore")

from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_log_error

# %%
# Read in CSV data
data = pd.read_csv('Resources/Final_Data.csv')

data.head()
# Out:
#    Zip_Code        Date  Date_Code  Year  Month  Sale_Price  Interest_Rate  \
# 0     32003  2019-01-01     201901  2019      1    244950.0         4.4640
# 1     32003  2019-02-01     201902  2019      2    270000.0         4.3700
# 2     32003  2019-03-01     201903  2019      3    275000.0         4.2650
# 3     32003  2019-04-01     201904  2019      4    264500.0         4.1425
# 4     32003  2019-05-01     201905  2019      5    281000.0         4.0720
#
#    Property_Tax  Rent_Price  Household_Income  ...  FTE_Employed  Unemployed  \
# 0          3778        1113           94154.0  ...         10671        1069
# 1          3778        1113           94154.0  ...         10671        1069
# 2          3778        1113           94154.0  ...         10671        1069
# 3          3778        1113           94154.0  ...         10671        1069
# 4          3778        1113           94154.0  ...         10671        1069
#
#    Expense_Index  Average_Commute  Crime_Index Loan_Amount  Loan_Term  \
# 0            104               35           28    195960.0      360.0
# 1            104               35           28    216000.0      360.0
# 2            104               35           28    220000.0      360.0
# 3            104               35           28    211600.0      360.0
# 4            104               35           28    224800.0      360.0
#
#      Loan_R  Loan_Payment  Home_Affordability
# 0  1.003720    988.713278            0.126012
# 1  1.003642   1077.819242            0.137369
# 2  1.003554   1084.200547            0.138182
# 3  1.003452   1027.671397            0.130978
# 4  1.003393   1082.581718            0.137976
#
# [5 rows x 30 columns]

# %%
data.shape
# Out:
# (23510, 30)

# %% [markdown]
# ## Set aside 2021 data

# %%
ml_data_21 = data.loc[data.Year == 2021]
ml_data_21 = ml_data_21[['Zip_Code', 'Year', 'Month', 'Mobility_Rate', 'Expense_Index', 'Crime_Index' , 
                         'Total_Vacant', 'Total_Dwellings', 'Total_Sales', 'FHA_Count', 'Home_Affordability', 
                         'Rent_Affordability', 'Sale_Price']]
ml_data_21 = ml_data_21.sort_values(by = ['Zip_Code', 'Year', 'Month'], ascending = [True, True, True])

# %%
# Add columns for previous months' sales prices
ml_data_21['Last_Month_Price'] = ml_data_21.groupby(['Zip_Code'])['Sale_Price'].shift()
ml_data_21['Last_Month_Diff'] = ml_data_21.groupby(['Zip_Code'])['Last_Month_Price'].diff()

ml_data_21['Last_2Month_Price'] = ml_data_21.groupby(['Zip_Code'])['Sale_Price'].shift(2)
ml_data_21['Last_2Month_Diff'] = ml_data_21.groupby(['Zip_Code'])['Last_2Month_Price'].diff()

ml_data_21['Last_3Month_Price'] = ml_data_21.groupby(['Zip_Code'])['Sale_Price'].shift(3)
ml_data_21['Last_3Month_Diff'] = ml_data_21.groupby(['Zip_Code'])['Last_3Month_Price'].diff()

# Drop columns not needed for X values
ml_data_21 = ml_data_21.drop(columns=['Zip_Code', 'Year', 'Month'])

# ml_data_21.replace([np.inf, -np.inf], np.nan, inplace=True)
# ml_data_21.dropna(inplace=True)

ml_data_21.head(20000)
# Out:
#        Mobility_Rate  Expense_Index  Crime_Index  Total_Vacant  \
# 24          0.182327            104           28           704
# 25          0.182327            104           28           704
# 26          0.182327            104           28           704
# 50          0.067037             82          118           964
# 51          0.067037             82          118           964
# ...              ...            ...          ...           ...
# 23481       0.141276             78          140          2780
# 23482       0.141276             78          140          2780
# 23507       0.143471             91          113          2976
# 23508       0.143471             91          113          2976
# 23509       0.143471             91          113          2976
#
#        Total_Dwellings  Total_Sales  FHA_Count  Home_Affordability  \
# 24               11724           39          6            0.124589
# 25               11724           30          8            0.140027
# 26               11724           70          4            0.147681
# 50                3247            6          0            0.153378
# 51                3247            3          1            0.062420
# ...                ...          ...        ...                 ...
# 23481             9249           57          1            0.225364
# 23482             9249           14          0            0.275304
# 23507            21551           81         10            0.202930
# 23508            21551          116          7            0.201553
# 23509            21551            7         12            0.416754
#
#        Rent_Affordability  Sale_Price  Last_Month_Price  Last_Month_Diff  \
# 24               0.141853    299900.0               NaN              NaN
# 25               0.141853    333800.0          299900.0              NaN
# 26               0.141853    339950.0          333800.0          33900.0
# 50               0.285180    132000.0               NaN              NaN
# 51               0.285180     53200.0          132000.0              NaN
# ...                   ...         ...               ...              ...
# 23481            0.209918    395000.0          345000.0              NaN
# 23482            0.209918    465950.0          395000.0          50000.0
# 23507            0.247189    305000.0               NaN              NaN
# 23508            0.247189    300000.0          305000.0              NaN
# 23509            0.247189    599000.0          300000.0          -5000.0
#
#        Last_2Month_Price  Last_2Month_Diff  Last_3Month_Price  \
# 24                   NaN               NaN                NaN
# 25                   NaN               NaN                NaN
# 26              299900.0               NaN                NaN
# 50                   NaN               NaN                NaN
# 51                   NaN               NaN                NaN
# ...                  ...               ...                ...
# 23481                NaN               NaN                NaN
# 23482           345000.0               NaN                NaN
# 23507                NaN               NaN                NaN
# 23508                NaN               NaN                NaN
# 23509           305000.0               NaN                NaN
#
#        Last_3Month_Diff
# 24                  NaN
# 25                  NaN
# 26                  NaN
# 50                  NaN
# 51                  NaN
# ...                 ...
# 23481               NaN
# 23482               NaN
# 23507               NaN
# 23508               NaN
# 23509               NaN
#
# [2543 rows x 16 columns]

# %% [markdown]
# ## 2019/2020 Data

# %%
# Select features for X
ml_data = data[['Zip_Code', 'Year', 'Month', 'Mobility_Rate', 'Expense_Index', 'Crime_Index' , 'Total_Vacant', 'Total_Dwellings', 'Total_Sales', 'FHA_Count', 'Home_Affordability', 'Rent_Affordability', 'Sale_Price' ]]

ml_data.shape
# Out:
# (23510, 13)

# %%
# Drop 2021 data
# index_names = ml_data[ml_data['Year'] == 2021 ].index
# ml_data.drop(index_names, inplace = True)

# ml_data.shape

# %%
# Create copy to try three-month training data
ml_data_3mo = ml_data.sort_values(by = ['Zip_Code', 'Year', 'Month'], ascending = [True, True, True])
ml_data_3mo.loc[ml_data_3mo.Year == 2020, "Month"] += 12
ml_data_3mo.loc[ml_data_3mo.Year == 2021, "Month"] += 24

ml_data_3mo.head(22000)
# Out:
#        Zip_Code  Year  Month  Mobility_Rate  Expense_Index  Crime_Index  \
# 0         32003  2019      1       0.182327            104           28
# 1         32003  2019      2       0.182327            104           28
# 2         32003  2019      3       0.182327            104           28
# 3         32003  2019      4       0.182327            104           28
# 4         32003  2019      5       0.182327            104           28
# ...         ...   ...    ...            ...            ...          ...
# 21995     34685  2021     26       0.139297             96          268
# 21996     34685  2021     27       0.139297             96          268
# 21997     34688  2019      1       0.152133            102          160
# 21998     34688  2019      2       0.152133            102          160
# 21999     34688  2019      3       0.152133            102          160
#
#        Total_Vacant  Total_Dwellings  Total_Sales  FHA_Count  \
# 0               704            11724           32          7
# 1               704            11724           41          2
# 2               704            11724           21          7
# 3               704            11724           42          3
# 4               704            11724           66          8
# ...             ...              ...          ...        ...
# 21995           746             8332           32          1
# 21996           746             8332           33          0
# 21997           449             3389           13          1
# 21998           449             3389           15          1
# 21999           449             3389            5          0
#
#        Home_Affordability  Rent_Affordability  Sale_Price
# 0                0.126012            0.141853    244950.0
# 1                0.137369            0.141853    270000.0
# 2                0.138182            0.141853    275000.0
# 3                0.130978            0.141853    264500.0
# 4                0.137976            0.141853    281000.0
# ...                   ...                 ...         ...
# 21995            0.150293            0.184243    315000.0
# 21996            0.185287            0.184243    375000.0
# 21997            0.232598            0.180844    405000.0
# 21998            0.182325            0.180844    321000.0
# 21999            0.192972            0.180844    344000.0
#
# [22000 rows x 13 columns]

# %%
# Add columns for previous months' sales prices
ml_data_3mo['Last_Month_Price'] = ml_data_3mo.groupby(['Zip_Code'])['Sale_Price'].shift()
ml_data_3mo['Last_Month_Diff'] = ml_data_3mo.groupby(['Zip_Code'])['Last_Month_Price'].diff()

ml_data_3mo['Last_2Month_Price'] = ml_data_3mo.groupby(['Zip_Code'])['Sale_Price'].shift(2)
ml_data_3mo['Last_2Month_Diff'] = ml_data_3mo.groupby(['Zip_Code'])['Last_2Month_Price'].diff()

ml_data_3mo['Last_3Month_Price'] = ml_data_3mo.groupby(['Zip_Code'])['Sale_Price'].shift(3)
ml_data_3mo['Last_3Month_Diff'] = ml_data_3mo.groupby(['Zip_Code'])['Last_3Month_Price'].diff()

ml_data_3mo.head()
# Out:
#    Zip_Code  Year  Month  Mobility_Rate  Expense_Index  Crime_Index  \
# 0     32003  2019      1       0.182327            104           28
# 1     32003  2019      2       0.182327            104           28
# 2     32003  2019      3       0.182327            104           28
# 3     32003  2019      4       0.182327            104           28
# 4     32003  2019      5       0.182327            104           28
#
#    Total_Vacant  Total_Dwellings  Total_Sales  FHA_Count  Home_Affordability  \
# 0           704            11724           32          7            0.126012
# 1           704            11724           41          2            0.137369
# 2           704            11724           21          7            0.138182
# 3           704            11724           42          3            0.130978
# 4           704            11724           66          8            0.137976
#
#    Rent_Affordability  Sale_Price  Last_Month_Price  Last_Month_Diff  \
# 0            0.141853    244950.0               NaN              NaN
# 1            0.141853    270000.0          244950.0              NaN
# 2            0.141853    275000.0          270000.0          25050.0
# 3            0.141853    264500.0          275000.0           5000.0
# 4            0.141853    281000.0          264500.0         -10500.0
#
#    Last_2Month_Price  Last_2Month_Diff  Last_3Month_Price  Last_3Month_Diff
# 0                NaN               NaN                NaN               NaN
# 1                NaN               NaN                NaN               NaN
# 2           244950.0               NaN                NaN               NaN
# 3           270000.0           25050.0           244950.0               NaN
# 4           275000.0            5000.0           270000.0           25050.0

# %%
# Drop columns not needed for X values
# Keeping Month this time
ml_data_3mo = ml_data_3mo.drop(columns=['Zip_Code', 'Year', 'Month'])

ml_data_3mo.shape
# Out:
# (23510, 16)

# %%
ml_data_3mo.replace([np.inf, -np.inf], np.nan, inplace=True)
ml_data_3mo.dropna(inplace=True)

ml_data_3mo.shape
# Out:
# (19896, 16)

# %%
ml_data_3mo.head()
# Out:
#    Mobility_Rate  Expense_Index  Crime_Index  Total_Vacant  Total_Dwellings  \
# 4       0.182327            104           28           704            11724
# 5       0.182327            104           28           704            11724
# 6       0.182327            104           28           704            11724
# 7       0.182327            104           28           704            11724
# 8       0.182327            104           28           704            11724
#
#    Total_Sales  FHA_Count  Home_Affordability  Rent_Affordability  Sale_Price  \
# 4           66          8            0.137976            0.141853    281000.0
# 5           43          3            0.130690            0.141853    275000.0
# 6           90          7            0.133641            0.141853    282500.0
# 7           64          5            0.125212            0.141853    269577.0
# 8           50          3            0.132660            0.141853    286000.0
#
#    Last_Month_Price  Last_Month_Diff  Last_2Month_Price  Last_2Month_Diff  \
# 4          264500.0         -10500.0           275000.0            5000.0
# 5          281000.0          16500.0           264500.0          -10500.0
# 6          275000.0          -6000.0           281000.0           16500.0
# 7          282500.0           7500.0           275000.0           -6000.0
# 8          269577.0         -12923.0           282500.0            7500.0
#
#    Last_3Month_Price  Last_3Month_Diff
# 4           270000.0           25050.0
# 5           275000.0            5000.0
# 6           264500.0          -10500.0
# 7           281000.0           16500.0
# 8           275000.0           -6000.0

# %% [markdown]
# ## Train/test

# %%
# Set X and y values
y = ml_data_3mo['Last_3Month_Price'].values

X = ml_data_3mo.drop(columns='Last_3Month_Price')

feature_names = X.columns

X
# Out:
#        Mobility_Rate  Expense_Index  Crime_Index  Total_Vacant  \
# 4           0.182327            104           28           704
# 5           0.182327            104           28           704
# 6           0.182327            104           28           704
# 7           0.182327            104           28           704
# 8           0.182327            104           28           704
# ...              ...            ...          ...           ...
# 23505       0.143471             91          113          2976
# 23506       0.143471             91          113          2976
# 23507       0.143471             91          113          2976
# 23508       0.143471             91          113          2976
# 23509       0.143471             91          113          2976
#
#        Total_Dwellings  Total_Sales  FHA_Count  Home_Affordability  \
# 4                11724           66          8            0.137976
# 5                11724           43          3            0.130690
# 6                11724           90          7            0.133641
# 7                11724           64          5            0.125212
# 8                11724           50          3            0.132660
# ...                ...          ...        ...                 ...
# 23505            21551          132         11            0.173497
# 23506            21551          142         16            0.196301
# 23507            21551           81         10            0.202930
# 23508            21551          116          7            0.201553
# 23509            21551            7         12            0.416754
#
#        Rent_Affordability  Sale_Price  Last_Month_Price  Last_Month_Diff  \
# 4                0.141853    281000.0          264500.0         -10500.0
# 5                0.141853    275000.0          281000.0          16500.0
# 6                0.141853    282500.0          275000.0          -6000.0
# 7                0.141853    269577.0          282500.0           7500.0
# 8                0.141853    286000.0          269577.0         -12923.0
# ...                   ...         ...               ...              ...
# 23505            0.247189    259750.0          285000.0          29000.0
# 23506            0.247189    297000.0          259750.0         -25250.0
# 23507            0.247189    305000.0          297000.0          37250.0
# 23508            0.247189    300000.0          305000.0           8000.0
# 23509            0.247189    599000.0          300000.0          -5000.0
#
#        Last_2Month_Price  Last_2Month_Diff  Last_3Month_Diff
# 4               275000.0            5000.0           25050.0
# 5               264500.0          -10500.0            5000.0
# 6               281000.0           16500.0          -10500.0
# 7               275000.0           -6000.0           16500.0
# 8               282500.0            7500.0           -6000.0
# ...                  ...               ...               ...
# 23505           256000.0            5000.0           -4000.0
# 23506           285000.0           29000.0            5000.0
# 23507           259750.0          -25250.0           29000.0
# 23508           297000.0           37250.0          -25250.0
# 23509           305000.0            8000.0           37250.0
#
# [19896 rows x 15 columns]

# %%
# Do test-train-split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
print(len(X_test))
print(len(y_test))
# Out:
# 4974
# 4974

# %%
# Fit Random Forest Regressor model
rfr_model = RandomForestRegressor(n_estimators=1000, n_jobs=-1, random_state=42)
rfr_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=1000, n_jobs=-1, random_state=42)

# %%
# Get R2 score
print(f"Training Data Score: {rfr_model.score(X_train, y_train)}")
print(f"Testing Data Score: {rfr_model.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.9925392163341774
# Testing Data Score: 0.976635657973184

# %% [markdown]
# ## Prediction

# %%
def rmsle(ytrue, ypred):
    return np.sqrt(mean_squared_log_error(ytrue, ypred))

# %%
rf_pred = rfr_model.predict(X_test)

error = rmsle(y_test, rf_pred)
    
print('Mean Error = %.5f' % np.mean(error))
# Out:
# Mean Error = 0.04911

# %%
output = pd.DataFrame({'Predicted':rf_pred, 'Actual': y_test})
output
# Out:
#        Predicted    Actual
# 0     386609.700  382500.0
# 1     168674.175  169913.0
# 2     175304.980  175000.0
# 3     254050.886  255000.0
# 4      94048.819   96500.0
# ...          ...       ...
# 4969  181297.641  180000.0
# 4970  204364.500  205000.0
# 4971  157378.405  158000.0
# 4972  338255.311  337500.0
# 4973  328133.211  328000.0
#
# [4974 rows x 2 columns]

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'n_estimators': [100, 500, 1000,]}
grid = GridSearchCV(rfr_model, param_grid, verbose=3)
grid
# Out:
# GridSearchCV(estimator=RandomForestRegressor(n_estimators=1000, n_jobs=-1,
#                                              random_state=42),
#              param_grid={'n_estimators': [100, 500, 1000]}, verbose=3)

# %%
r2 = r2_score(yts, y_pred)
print(f'The R2 score for predicting sale prices of January, 2021 is {r2}.')
